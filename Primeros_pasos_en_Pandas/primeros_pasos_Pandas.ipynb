# %% [markdown]
# # Primeros Pasos

# %% [markdown]
# ## Series e indexacion

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '1.3.5'

# %%
sr = pd.Series([10,11,12,13,15], index=['a', 'b', 'c', 'd', 'e'])

# %%
sr.values
# Out:
# array([10, 11, 12, 13, 15])

# %%
sr.shape
# Out:
# (5,)

# %%
sr['a':'c']
# Out:
# a    10
# b    11
# c    12
# dtype: int64

# %%
diccionario = {
    'MX': 300,
    'GM': 200,
    'BT': 123,
    'SP': 321,
    'US': 573,
}

# %%
diccionario.keys()
# Out:
# dict_keys(['MX', 'GM', 'BT', 'SP', 'US'])

# %%
diccionario['MX']
# Out:
# 300

# %%
pd.Series(diccionario)
# Out:
# MX    300
# GM    200
# BT    123
# SP    321
# US    573
# dtype: int64

# %% [markdown]
# ## DataFrames

# %%
dicc_datos = {
    'MX':900,
    'ES':800,
    'US':700
}

# %%
pd.Series(dicc_datos)
# Out:
# MX    900
# ES    800
# US    700
# dtype: int64

# %%
dicc_datos = {
    'MX':[900, 988, 832],
    'ES':[800, 987, 324],
    'US':[700, 354, 954]
}

# %%
df = pd.DataFrame(dicc_datos)
df
# Out:
#     MX   ES   US
# 0  900  800  700
# 1  988  987  354
# 2  832  324  954

# %%
dict_data = {
    'edad': [10,9,13,14,12,11,12],
    'cm': [115,110,130,155,125,120,125],
    'pais':['co','mx','co','mx','mx','ch','ch'],
    'genero':['M','F','F','M','M','M','F'],
    'Q1':[5,10,8,np.nan,7,8,3],
    'Q2':[7,9,9,8,8,8,9]
}

# %%
df_2 = pd.DataFrame(dict_data)

# %%
df_2
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df_2 = pd.DataFrame(dict_data, index=['ana', 'benito', 'juan', 'daniel', 'fabian', 'gabriel', 'erick'])
df_2
# Out:
#          edad   cm pais genero    Q1  Q2
# ana        10  115   co      M   5.0   7
# benito      9  110   mx      F  10.0   9
# juan       13  130   co      F   8.0   9
# daniel     14  155   mx      M   NaN   8
# fabian     12  125   mx      M   7.0   8
# gabriel    11  120   ch      M   8.0   8
# erick      12  125   ch      F   3.0   9

# %%
df_2.index
# Out:
# Index(['ana', 'benito', 'juan', 'daniel', 'fabian', 'gabriel', 'erick'], dtype='object')

# %%
df_2.columns
# Out:
# Index(['edad', 'cm', 'pais', 'genero', 'Q1', 'Q2'], dtype='object')

# %%
df_2.values
# Out:
# array([[10, 115, 'co', 'M', 5.0, 7],
#        [9, 110, 'mx', 'F', 10.0, 9],
#        [13, 130, 'co', 'F', 8.0, 9],
#        [14, 155, 'mx', 'M', nan, 8],
#        [12, 125, 'mx', 'M', 7.0, 8],
#        [11, 120, 'ch', 'M', 8.0, 8],
#        [12, 125, 'ch', 'F', 3.0, 9]], dtype=object)

# %%
df_2[['edad', 'Q1']]
# Out:
#          edad    Q1
# ana        10   5.0
# benito      9  10.0
# juan       13   8.0
# daniel     14   NaN
# fabian     12   7.0
# gabriel    11   8.0
# erick      12   3.0

# %%
df_2['edad'] > 12
# Out:
# ana        False
# benito     False
# juan        True
# daniel      True
# fabian     False
# gabriel    False
# erick      False
# Name: edad, dtype: bool

# %%
df_2[df_2['edad'] > 12]
# Out:
#         edad   cm pais genero   Q1  Q2
# juan      13  130   co      F  8.0   9
# daniel    14  155   mx      M  NaN   8

# %%
df_2[ (df_2['edad'] >= 12) & (df_2['pais']=='mx') ]
# Out:
#         edad   cm pais genero   Q1  Q2
# daniel    14  155   mx      M  NaN   8
# fabian    12  125   mx      M  7.0   8

# %%
df_2.query('edad > 12')
# Out:
#         edad   cm pais genero   Q1  Q2
# juan      13  130   co      F  8.0   9
# daniel    14  155   mx      M  NaN   8

# %%
df_2['Q2'] > df_2['Q1']
# Out:
# ana         True
# benito     False
# juan        True
# daniel     False
# fabian      True
# gabriel    False
# erick       True
# dtype: bool

# %%
df_2[ df_2['Q2'] > df_2['Q1'] ]
# Out:
#         edad   cm pais genero   Q1  Q2
# ana       10  115   co      M  5.0   7
# juan      13  130   co      F  8.0   9
# fabian    12  125   mx      M  7.0   8
# erick     12  125   ch      F  3.0   9
